# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/BikashPandey17/BikashPandey17.github.io/blob/master/session0.ipynb)

# %%
import os

# %%
import urllib.request

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
os.mkdir('img_align_celeba')

# %%
for img_i in range(1, 11):
  f = '000%03d.jpg' % img_i
  url = 'https://s3.amazonaws.com/cadl/celeb-align/' + f
  print(url, end='\r')
  urllib.request.urlretrieve(url, os.path.join('img_align_celeba', f))

# %%
help(os.listdir)
# Out:
# Help on built-in function listdir in module posix:
#
# listdir(path=None)
#     Return a list containing the names of the files in the directory.
#
#     path can be specified as either str or bytes.  If path is bytes,
#       the filenames returned will also be bytes; in all other circumstances
#       the filenames returned will be str.
#     If path is None, uses the path='.'.
#     On some platforms, path may also be specified as an open file descriptor;\
#       the file descriptor must refer to a directory.
#       If this functionality is unavailable, using it raises NotImplementedError.
#
#     The list is in arbitrary order.  It does not include the special
#     entries '.' and '..' even if they are present in the directory.

# %%
files = os.listdir('img_align_celeba')

# %%
files
# Out:
# ['000010.jpg',
#  '000001.jpg',
#  '000003.jpg',
#  '000002.jpg',
#  '000009.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000004.jpg',
#  '000008.jpg',
#  '000005.jpg']

# %%
[file_i for file_i in os.listdir('img_align_celeba')
 if '.jpg' in file_i or '.png' in file_i or '.jpeg' in file_i]
# Out:
# ['000010.jpg',
#  '000001.jpg',
#  '000003.jpg',
#  '000002.jpg',
#  '000009.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000004.jpg',
#  '000008.jpg',
#  '000005.jpg']

# %%
files = [file_i for file_i in os.listdir('img_align_celeba')
 if '.jpg' in file_i or '.png' in file_i or '.jpeg' in file_i]

# %%
print(files[0])
# Out:
# 000010.jpg

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
help(plt)

# %%
plt.imread?

# %%
import numpy as np

# %%
print(os.path.join('img_align_celeba',files[0]))
plt.imread(os.path.join('img_align_celeba',files[0]))
# Out:
# img_align_celeba/000010.jpg
# array([[[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        [[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        [[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        ...,
#
#        [[190, 148, 134],
#         [190, 148, 134],
#         [190, 148, 134],
#         ...,
#         [ 16,  16,  24],
#         [ 16,  16,  24],
#         [ 16,  16,  24]],
#
#        [[194, 152, 138],
#         [193, 151, 137],
#         [193, 151, 137],
#         ...,
#         [ 17,  18,  23],
#         [ 17,  18,  23],
#         [ 17,  18,  23]],
#
#        [[194, 152, 138],
#         [193, 151, 137],
#         [193, 151, 137],
#         ...,
#         [ 18,  17,  23],
#         [ 17,  18,  23],
#         [ 17,  18,  23]]], dtype=uint8)

# %%
files = [os.path.join('img_align_celeba'), file_i for file_i in os.listdir('img_align_celeba')
 if '.jpg' in file_i or '.png' in file_i or '.jpeg' in file_i]
# Out:
#   File "<ipython-input-16-5e863f38c2f8>", line 1
#     files = [os.path.join('img_align_celeba'), file_i for file_i in os.listdir('img_align_celeba')
#                                                         ^
# SyntaxError: invalid syntax

# %%
files = [os.path.join('img_align_celeba', file_i) for file_i in os.listdir('img_align_celeba')
 if '.jpg' in file_i or '.png' in file_i or '.jpeg' in file_i]

# %%
img= plt.imread(files[0])

# %%
img
# Out:
# array([[[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        [[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        [[  3,   4,   8],
#         [  3,   4,   8],
#         [  3,   4,   8],
#         ...,
#         [ 28,  30,  51],
#         [ 29,  31,  54],
#         [ 29,  31,  54]],
#
#        ...,
#
#        [[190, 148, 134],
#         [190, 148, 134],
#         [190, 148, 134],
#         ...,
#         [ 16,  16,  24],
#         [ 16,  16,  24],
#         [ 16,  16,  24]],
#
#        [[194, 152, 138],
#         [193, 151, 137],
#         [193, 151, 137],
#         ...,
#         [ 17,  18,  23],
#         [ 17,  18,  23],
#         [ 17,  18,  23]],
#
#        [[194, 152, 138],
#         [193, 151, 137],
#         [193, 151, 137],
#         ...,
#         [ 18,  17,  23],
#         [ 17,  18,  23],
#         [ 17,  18,  23]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (218, 178, 3)

# %%
plt.figure()
plt.imshow(img[:, :, 0])
plt.figure()
plt.imshow(img[:, :, 1])
plt.figure()
plt.imshow(img[:, :, 2])

# %%
np.min(img), np.max(img)
# Out:
# (0, 255)

# %%
#numpy arrays have a field which will tell us how many bits they are using: dtype:
img.dtype
# Out:
# dtype('uint8')

# %%
#to pick a random image from our list of files, we can use the numpy random module:
print(np.random.randint(0, len(files)))
# Out:
# 7

# %%
#selecting a random file from 0to (length of number of files)
filename = files[np.random.randint(0, len(files))]
img = plt.imread(filename)
plt.imshow(img)

# %%
def plot_image(filename):
  img = plt.imread(filename)
  plt.imshow(img)

# %%
f = files[np.random.randint(0, len(files))]
#plot_image(f)
#or
plot_image(files[np.random.randint(0,len(files))])
np.ndarray?

# %%
#for own image dataset we need to crop
def imcrop_tosquare(img):
  """Make any image a square image.
  
  Parameters
  ----------
  img : np.ndarray
        Input image to crop, assumed at least 2d.
        
  Returns
  -------
  crop : np.ndarray
          Cropped image.
  """
  if img.shape[0] > img.shape[1] : 
    extra = (img.shape[0] - img.shape[1])
    if extra % 2 == 0:
      crop = img[extra // 2:-extra //2, :]
    else:
      crop = img[max(0, extra // 2 + 1):min(-1, -(extra // 2)), :]
  elif img.shape[1] > img.shape[0]:
      extra = (img.shape[1] - img.shape[0])
      if extra % 2 == 0 :
          crop = img[:,extra // 2 :-extra // 2]
      else:
        crop = img[:, max(0, extra // 2 + 1):min(-1, -(extra//2))]
  else:
        crop = img 
  return crop

# %%
# // means to do integer division instead of flosting point division

# %%
def imcrop(img , amt):
  if amt <= 0 or amt>= 1:
    return img
  row_i = int(img.shape[0] * amt) // 2
  col_i = int(img.shape[1] * amt) // 2
  return img[row_i:-row_i,col_i:-col_i]

# %%
#for resizing the image we will use a python library scipy
from scipy.misc import imresize
imresize?

# %%
square = imcrop_tosquare(img)
crop = imcrop(square, 0.2)
rsz = imresize(crop, (64, 64))
plt.imshow(rsz)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
plt.imshow(rsz, interpolation='nearest')

# %%
mean_img = np.mean(rsz, axis=2)
print(mean_img.shape)
plt.imshow(mean_img, cmap='gray')
# Out:
# (64, 64)

# %%
imgs = []
for file_i in files : 
  img = plt.imread(file_i)
  square = imcrop_tosquare(img)
  crop = imcrop(square, 0.2)
  rsz = imresize(crop, (64,64))
  imgs.append(rsz)
print(len(imgs))
# Out:
# 10
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
plt.imshow(imgs[2])

# %%
imgs[2].shape
# Out:
# (64, 64, 3)

# %%
# batch dimension
data = np.array(imgs)
data.shape
# Out:
# (10, 64, 64, 3)
